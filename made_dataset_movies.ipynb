# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathambiradr12345/DATA-SCEINCE-PROJECTS/blob/main/made_dataset_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=2dd1cc1d47f9aa85b2c234c2613432a4').json()

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zOpe0eHsq0A2NvNyBbtT6sj53qV.jpg',
#    'genre_ids': [28, 878, 35, 10751],
#    'id': 939243,
#    'original_language': 'en',
#    'original_title': 'Sonic the Hedgehog 3',
#    'overview': 'Sonic, Knuckles, and Tails reunite against a powerful new adversary, Shadow, a mysterious villain with powers unlike anything they have faced before. With their abilities outmatched in every way, Team Sonic must seek out an unlikely alliance in hopes of stopping Shadow and protecting the planet.',
#    'popularity': 2525.912,
#    'poster_path': '/d8Ryb8AunYAuycVKDp5HpdWPKgC.jpg',
#    'release_date': '2024-12-19',
#    'title': 'Sonic the Hedgehog 3',
#    'video': False,
#    'vote_average': 7.6,
#    'vote_count': 589},
#   {'adult': False,
#    'backdrop_path': '/oHPoF0Gzu8xwK4CtdXDaWdcuZxZ.jpg',
#    'genre_ids': [12, 10751, 16],
#    'id': 762509,
#    'original_language': 'en',
# ...

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]
for i in response['results']:
  popularity.append(i['popularity'])
  vote_count.append(i['vote_count'])
  original_language.append(i['original_language'])
  title.append(i['title'])
  vote_average.append(i['vote_average'])
  overview.append(i['overview'])
  release_date.append(i['release_date'])
d={'popularity':popularity,'vote_count':vote_count,'original_language':original_language,'title':title,'vote_average':vote_average,'overview':overview,'release_date':release_date}
import pandas as pd
df=pd.DataFrame(d)

# %%
df
# Out:
#     popularity  vote_count original_language  \
# 0     2525.912         589                en
# 1     2393.715         681                en
# 2     1720.821        2343                en
# 3     1694.909        2371                en
# 4     1432.939         849                en
# 5     1373.294         118                no
# 6     1270.610        1289                en
# 7     1682.267         426                en
# 8     1096.460         188                en
# 9      972.760        2034                en
# 10    1049.714         314                en
# 11    1035.271         864                es
# 12     930.553          72                ja
# 13     808.580         332                en
# 14     740.205         131                en
# 15     647.826           8                zh
# 16     727.215        3272                en
# 17     627.522        1647                en
# 18     635.112         766                lv
# 19     591.473        3390                es
#
# ...

# %%
import requests
import pandas as pd

final = []  # Initialize final as a list to store DataFrames

for j in range(1, 501):
    response = requests.get(
        'https://api.themoviedb.org/3/movie/popular?api_key=2dd1cc1d47f9aa85b2c234c2613432a4'
    ).json()  # Removed unnecessary .format(j)
    popularity = []
    vote_count = []
    original_language = []
    title = []
    vote_average = []
    overview = []
    release_date = []
    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])
    d = {
        'popularity': popularity,
        'vote_count': vote_count,
        'original_language': original_language,
        'title': title,
        'vote_average': vote_average,
        'overview': overview,
        'release_date': release_date
    }
    df = pd.DataFrame(d)
    final.append(df)  # Append the DataFrame to the list

final = pd.concat(final, ignore_index=True)  # Concatenate all DataFrames in the list

# %%
final.shape
# Out:
# (10000, 7)

# %%
final.to_csv('movies.csv')
